# %%
import pandas as pd
import numpy as np 
import seaborn as sns

# %%
df = pd.read_csv("creditcard.csv/creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
#this is unbalanced dataset

# %%
legit=df[df.Class==0]
fraud= df[df.Class==1]

# %%
legit
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
fraud
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Under_Sampling
#build a sample dataset containing similar distribution of normal transactionsand Fraudlent transaction
#no of fraud transaction---->>492

# %%
legit_sample= legit.sample(n=492)

# %%
legit_sample
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 253684  156360.0 -1.046464  1.850070 -0.617430 -0.936587  0.967356 -0.718273
# 39096    39692.0 -0.849980  0.404229  3.529736  3.141990 -0.658355  2.310832
# 94447    64891.0  1.286993 -0.592533 -0.288561 -0.849655 -0.441281 -0.455844
# 217089  140757.0 -2.908186 -0.735791 -1.337794 -0.435368  0.928990 -0.554714
# 161017  113793.0 -0.475829  1.028854  0.905904 -0.350517 -0.171447 -0.286761
# ...          ...       ...       ...       ...       ...       ...       ...
# 77072    56875.0 -1.791436 -5.441420 -0.364418  0.646476 -2.768361  0.871950
# 165407  117410.0  2.147540 -0.851628 -1.199278 -0.113530 -0.780837 -0.905223
# 5235      5043.0 -0.610353  0.876268  3.134572  2.260169  0.001185  0.268439
# 2990      2542.0 -0.570758  1.017213  1.080374 -0.536459  0.897405  0.208530
# 39471    39851.0  1.253034 -0.427867 -0.591240 -1.550570 -0.157335 -0.706265
#
# ...

# %%
#concatenating both datasets

# %%
new_df=pd.concat([legit_sample, fraud], axis=0)

# %%
new_df.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 253684  156360.0 -1.046464  1.850070 -0.617430 -0.936587  0.967356 -0.718273
# 39096    39692.0 -0.849980  0.404229  3.529736  3.141990 -0.658355  2.310832
# 94447    64891.0  1.286993 -0.592533 -0.288561 -0.849655 -0.441281 -0.455844
# 217089  140757.0 -2.908186 -0.735791 -1.337794 -0.435368  0.928990 -0.554714
# 161017  113793.0 -0.475829  1.028854  0.905904 -0.350517 -0.171447 -0.286761
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 253684  1.423253 -0.652819  1.350280  ...  0.063241  1.270808 -0.160536
# 39096  -1.079524  0.863694  0.162882  ...  0.193304  0.970954 -0.388370
# 94447  -0.116963 -0.153081 -1.331307  ... -0.762524 -1.977262  0.110089
# 217089 -0.528214 -2.368008 -0.077728  ... -1.746179  0.450909  1.844204
# 161017 -0.026424 -1.701274  0.372654  ...  1.554027 -0.233473  0.384441
#
# ...

# %%
new_df.Class.value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
new_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      92719.711382  0.045026 -0.006940  0.028742 -0.052888 -0.029685
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.098313 -0.018907  0.011244  0.085497  ...  0.027618 -0.009944
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.021745  0.005066 -0.030797  0.008628  0.010479 -0.010936 -0.011989
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       80.293577
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#split data into features and target
x=new_df.drop("Class", axis=1)

# %%
x
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 253684  156360.0 -1.046464  1.850070 -0.617430 -0.936587  0.967356 -0.718273
# 39096    39692.0 -0.849980  0.404229  3.529736  3.141990 -0.658355  2.310832
# 94447    64891.0  1.286993 -0.592533 -0.288561 -0.849655 -0.441281 -0.455844
# 217089  140757.0 -2.908186 -0.735791 -1.337794 -0.435368  0.928990 -0.554714
# 161017  113793.0 -0.475829  1.028854  0.905904 -0.350517 -0.171447 -0.286761
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
y=new_df.Class

# %%
y
# Out:
# 253684    0
# 39096     0
# 94447     0
# 217089    0
# 161017    0
#          ..
# 279863    1
# 280143    1
# 280149    1
# 281144    1
# 281674    1
# Name: Class, Length: 984, dtype: int64

# %%
#split into train nd test 

from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test= train_test_split(x,y,test_size=0.2, random_state=2)

# %%
x_train
# Out:
#            Time        V1        V2         V3         V4        V5        V6  \
# 42007   40918.0 -3.140260  3.367342  -2.778931   3.859701 -1.159518 -0.721552
# 61401   49815.0 -1.632933  0.059875   1.759088  -0.255133  0.734990 -0.452811
# 113887  73249.0  1.199169  0.169248   0.371965   0.643708 -0.587581 -0.911793
# 12939   22734.0  1.186236 -0.274179   1.025449  -0.568543 -0.904330 -0.289327
# 2770     2310.0 -0.968809  1.137849   0.878852  -0.618653  0.093800 -0.798155
# ...         ...       ...       ...        ...        ...       ...       ...
# 10568   17520.0 -5.268053  9.067613 -15.960728  10.296603 -4.708241 -3.395375
# 27749   34687.0 -0.860827  3.131790  -5.052968   5.420941 -2.494141 -1.811287
# 623       472.0 -3.043541 -3.157307   1.088463   2.288644  1.359805 -1.064823
# 9252    13323.0 -5.454362  8.287421 -12.752811   8.594342 -3.106002 -3.179949
# 11330   19725.0  1.259003  0.395851   0.425642   0.905329 -0.382167 -1.046495
#
# ...

# %%
x_test
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 97433    66218.0   1.557485  -0.902443   0.111260  -1.521689  -1.031020
# 11343    19762.0 -14.179165   7.421370 -21.405836  11.927512  -7.974281
# 150715   93965.0 -11.397727   7.763953 -18.572307   6.711855 -10.174216
# 210583  138048.0  -2.596449   2.720676  -3.747523  -1.639548   1.416832
# 58761    48533.0   1.243848   0.524526  -0.538884   1.209196   0.479538
# ...          ...        ...        ...        ...        ...        ...
# 251881  155542.0   1.868226   1.363077  -1.994934   4.173516   1.239751
# 210611  138056.0  -0.423090   0.477995   0.435293  -0.418383   0.076246
# 15539    26931.0 -22.561699  13.208904 -24.643819   6.232532 -16.905611
# 50211    44393.0  -4.617461   3.663395  -5.297446   3.880960  -3.263551
# 212141  138733.0   1.910544  -0.359504  -0.914441   0.436650  -0.191475
#
#               V6         V7         V8        V9  ...       V20       V21  \
# ...

# %%
#model training 

# logistic Regression
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
#model Evaluation
#Accuracy
from sklearn.metrics import accuracy_score

# %%
x_train_pred= lr.predict(x_train)

# %%
training_accuracy= accuracy_score(x_train_pred, y_train)
training_accuracy
# Out:
# 0.9415501905972046

# %%
#test_accuracy
x_test_pred= lr.predict(x_test)
x_test_accuracy= accuracy_score(x_test_pred, y_test)
x_test_accuracy
# Out:
# 0.934010152284264
